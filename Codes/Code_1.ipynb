# %%
import pandas as pd
import seaborn as sns # For plotting
import matplotlib.pyplot as plt # For showing plots

# %%
df = pd.read_csv('Permanent_Crop_NUTS2.csv', sep=",")
df.head(200)
# Out:
#      NutsID  year    area  permanent_crop_ID  \
# 0        11  1989  223736                 33
# 1        11  1999  228323                 34
# 2        11  2009  218545                 35
# 3        11  2019  255954                 36
# 4        11  1989   10696                 37
# ..      ...   ...     ...                ...
# 195      30  2019    2322             107780
# 196      30  1989     261             107781
# 197      30  1999     219             107782
# 198      30  2009     278             107783
# 199      30  2019     267             107784
#
#                                              crop_name  \
# 0                                                Total
# 1                                                Total
# 2                                                Total
# 3                                                Total
# 4    Fresh fruit plantations (excluding citrus plan...
# ..                                                 ...
# 195                                              Total
# 196  Fresh fruit plantations (excluding citrus plan...
# 197  Fresh fruit plantations (excluding citrus plan...
# 198  Fresh fruit plantations (excluding citrus plan...
# 199  Fresh fruit plantations (excluding citrus plan...
#
#                      region_name region_level
# 0                          Norte        NUTS2
# 1                          Norte        NUTS2
# 2                          Norte        NUTS2
# 3                          Norte        NUTS2
# 4                          Norte        NUTS2
# ..                           ...          ...
# 195  Região Autónoma da Madeira         NUTS2
# 196  Região Autónoma da Madeira         NUTS2
# 197  Região Autónoma da Madeira         NUTS2
# 198  Região Autónoma da Madeira         NUTS2
# 199  Região Autónoma da Madeira         NUTS2
#
# [200 rows x 7 columns]

# %%
# Filtrar los datos por crop_name "Total"
df_filtered = df[df['crop_name'] == "Total"]

# Configurar el tamaño de la figura y crear subplots
fig, axes = plt.subplots(2, 2, figsize=(16, 10), sharey=True)

# Crear una paleta de colores para las regiones
unique_regions = df_filtered['region_name'].unique()
palette = dict(zip(unique_regions, sns.color_palette('Set3', len(unique_regions))))

for ax, year in zip(axes.flatten(), df_filtered['year'].unique()):
    sns.barplot(x='region_name', y='area', data=df_filtered[df_filtered['year'] == year], palette=palette, ax=ax)
    ax.set_title(f'Año {year}')
    ax.set_xlabel('Región')
    ax.set_ylabel('Área sembrada')
    ax.set_xticks([])


# Añadir una leyenda fuera del bucle
handles = [plt.Line2D([0], [0], color=palette[region], lw=4) for region in unique_regions]
labels = unique_regions
fig.legend(handles, labels, loc='center left', bbox_to_anchor=(0.84, 0.5))
plt.tight_layout(rect=[0, 0, 0.85, 1])  # Ajustar el layout para dar espacio a la leyenda
plt.show()
# Out:
# c:\Users\cespe\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\cespe\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\cespe\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\cespe\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\cespe\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\cespe\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\cespe\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\cespe\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df_filtered.head(50)
# Out:
#      NutsID  year    area  permanent_crop_ID crop_name  \
# 0        11  1989  223736                 33     Total
# 1        11  1999  228323                 34     Total
# 2        11  2009  218545                 35     Total
# 3        11  2019  255954                 36     Total
# 32       15  1989   59888              48705     Total
# 33       15  1999   56309              48706     Total
# 34       15  2009   45007              48707     Total
# 35       15  2019   56754              48708     Total
# 64       16  1989  252705              51425     Total
# 65       16  1999  213178              51426     Total
# 66       16  2009  157603              51427     Total
# 67       16  2019  168086              51428     Total
# 96       17  1989   23694              86017     Total
# 97       17  1999   14732              86018     Total
# 98       17  2009   14060              86019     Total
# 99       17  2019   16428              86020     Total
# 128      18  1989  220942              90433     Total
# 129      18  1999  192689              90434     Total
# 130      18  2009  251006              90435     Total
# 131      18  2019  358544              90436     Total
# 160      20  1989    4769             102081     Total
# 161      20  1999    3662             102082     Total
# 162      20  2009    2021             102083     Total
# 163      20  2019    2574             102084     Total
# 192      30  1989    3679             107777     Total
# 193      30  1999    2735             107778     Total
# 194      30  2009    2482             107779     Total
# 195      30  2019    2322             107780     Total
#
#                       region_name region_level
# 0                           Norte        NUTS2
# 1                           Norte        NUTS2
# 2                           Norte        NUTS2
# 3                           Norte        NUTS2
# 32                        Algarve        NUTS2
# 33                        Algarve        NUTS2
# 34                        Algarve        NUTS2
# 35                        Algarve        NUTS2
# 64                         Centro        NUTS2
# 65                         Centro        NUTS2
# 66                         Centro        NUTS2
# 67                         Centro        NUTS2
# 96   Área Metropolitana de Lisboa        NUTS2
# 97   Área Metropolitana de Lisboa        NUTS2
# 98   Área Metropolitana de Lisboa        NUTS2
# 99   Área Metropolitana de Lisboa        NUTS2
# 128                      Alentejo        NUTS2
# 129                      Alentejo        NUTS2
# 130                      Alentejo        NUTS2
# 131                      Alentejo        NUTS2
# 160   Região Autónoma dos Açores         NUTS2
# 161   Região Autónoma dos Açores         NUTS2
# 162   Região Autónoma dos Açores         NUTS2
# 163   Região Autónoma dos Açores         NUTS2
# 192   Região Autónoma da Madeira         NUTS2
# 193   Região Autónoma da Madeira         NUTS2
# 194   Região Autónoma da Madeira         NUTS2
# 195   Região Autónoma da Madeira         NUTS2
